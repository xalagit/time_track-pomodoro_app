# %% [markdown]
# Esto es para entender lo que hago

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Crear grafo dirigido
G = nx.DiGraph()

# Nombres de los módulos
modules = ["main.py", "gui.py", "timer.py", "database.py", "stats.py"]
G.add_nodes_from(modules)

# Conexiones entre archivos
edges = [
    ("main.py", "database.py"),
    ("main.py", "gui.py"),
    ("gui.py", "timer.py"),
    ("gui.py", "stats.py"),
    ("timer.py", "database.py")
]

G.add_edges_from(edges)

# Layout visual
pos = nx.spring_layout(G, seed=42)

# Dibujar grafo
plt.figure(figsize=(10, 6))
nx.draw_networkx_nodes(G, pos, node_color="#66b3ff", node_size=2500)
nx.draw_networkx_edges(G, pos, edge_color="gray", arrows=True, arrowsize=25)
nx.draw_networkx_labels(G, pos, font_size=12, font_family="monospace")

plt.title("📊 Diagrama de interacción entre módulos de la Pomodoro App", fontsize=14)
plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import networkx as nx
#       4 # Crear grafo dirigido
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ![image.png](attachment:image.png)
